# %% [markdown]
# # Ressources

# %%
import pandas as pd
from sklearn.metrics import make_scorer, confusion_matrix
import pickle
import numpy as np
from imblearn import pipeline
import shap

# API avec Dash (en lien avec plotly express)

# https://plotly.com/dash/app-manager/
# https://medium.com/@olegkomarov_77860/how-to-embed-a-dash-app-into-an-existing-flask-app-ea05d7a2210b
# https://towardsdatascience.com/web-visualization-with-plotly-and-flask-3660abf9c946
# https://vikinganalytics.github.io/daeploy-docs/1.0.1/content/special_usecases/ui_plotly_dash.html#plotly-dash-application-as-part-of-a-sdk-based-application



from dash import Dash, dcc, html, Input, Output
import plotly.express as px

# %% [markdown]
# # Data

# %%
df_api = pd.read_csv('api/data_api.csv')

# %% [markdown]
# # On modifie la data qui servira à l'API

# %%
df_api.drop(['TARGET'], axis=1, inplace=True)
df_api.set_index('SK_ID_CURR', inplace=True)
df_api = df_api.iloc[:100] # on ne prend qu'un échantillon pour l'exemple
df_api = df_api.to_dict('index')

df_api
# Out:
# {100002: {'PAYMENT_RATE': 0.0607492667810303,
#   'EXT_SOURCE_1': 0.0830369673913225,
#   'EXT_SOURCE_3': 0.1393757800997895,
#   'EXT_SOURCE_2': 0.2629485927471776,
#   'DAYS_BIRTH': 9461,
#   'AMT_ANNUITY': 24700.5,
#   'DAYS_EMPLOYED': -637.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 24.0,
#   'DAYS_ID_PUBLISH': -2120,
#   'INCOME_CREDIT_PERC': 0.1219777777777777,
#   'ACTIVE_DAYS_CREDIT_MAX': -103.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -49.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -3648.0,
#   'DAYS_EMPLOYED_PERC': 0.0673290349857309,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 780.0,
#   'AMT_CREDIT': 406597.5,
#   'PREV_CNT_PAYMENT_MEAN': 24.0,
#   'AMT_GOODS_PRICE': 351000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 219625.695,
#   'REGION_POPULATION_RELATIVE': 0.018801,
#   'INSTAL_DBD_SUM': 388.0,
#   'DAYS_LAST_PHONE_CHANGE': -1134.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 1681.029,
#   'CLOSED_DAYS_CREDIT_MAX': -476.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 85.0,
#   'APPROVED_DAYS_DECISION_MAX': -606.0,
#   'POS_MONTHS_BALANCE_SIZE': 19.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 481988.565,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -15.5,
#   'BURO_DAYS_CREDIT_MAX': -103.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 780.0,
#   'INSTAL_AMT_PAYMENT_MIN': 9251.775,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 780.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -572.5,
#   'INSTAL_DBD_MAX': 31.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 63844.5,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 49156.2,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 780.0},
#  100003: {'PAYMENT_RATE': 0.0275983231574736,
#   'EXT_SOURCE_1': 0.3112673113812225,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6222457752555098,
#   'DAYS_BIRTH': 16765,
#   'AMT_ANNUITY': 35698.5,
#   'DAYS_EMPLOYED': -1188.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -291,
#   'INCOME_CREDIT_PERC': 0.1322166666666666,
#   'ACTIVE_DAYS_CREDIT_MAX': -606.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -544.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -1186.0,
#   'DAYS_EMPLOYED_PERC': 0.0708619147032508,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 1216.0,
#   'AMT_CREDIT': 1293502.5,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 1129500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1618864.65,
#   'REGION_POPULATION_RELATIVE': 0.0035409999999999,
#   'INSTAL_DBD_SUM': 179.0,
#   'DAYS_LAST_PHONE_CHANGE': -828.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -775.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -420.0,
#   'APPROVED_DAYS_DECISION_MAX': -746.0,
#   'POS_MONTHS_BALANCE_SIZE': 28.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 810000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -43.0,
#   'BURO_DAYS_CREDIT_MAX': -606.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1216.0,
#   'INSTAL_AMT_PAYMENT_MIN': 6662.97,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1216.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -606.0,
#   'INSTAL_DBD_MAX': 14.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 69133.5,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 1216.0},
#  100004: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.7295666907060153,
#   'EXT_SOURCE_2': 0.5559120833904428,
#   'DAYS_BIRTH': 19046,
#   'AMT_ANNUITY': 6750.0,
#   'DAYS_EMPLOYED': -225.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 4.0,
#   'DAYS_ID_PUBLISH': -2531,
#   'INCOME_CREDIT_PERC': 0.1,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -727.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -4260.0,
#   'DAYS_EMPLOYED_PERC': 0.0118135041478525,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 135000.0,
#   'PREV_CNT_PAYMENT_MEAN': 4.0,
#   'AMT_GOODS_PRICE': 135000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 21288.465,
#   'REGION_POPULATION_RELATIVE': 0.010032,
#   'INSTAL_DBD_SUM': 23.0,
#   'DAYS_LAST_PHONE_CHANGE': -815.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -408.0,
#   'OWN_CAR_AGE': 26.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -382.0,
#   'APPROVED_DAYS_DECISION_MAX': -815.0,
#   'POS_MONTHS_BALANCE_SIZE': 4.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -408.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -382.0,
#   'INSTAL_AMT_PAYMENT_MIN': 5357.25,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 11.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 94518.9,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100006: {'PAYMENT_RATE': 0.0949413542491185,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6504416904014653,
#   'DAYS_BIRTH': 19005,
#   'AMT_ANNUITY': 29686.5,
#   'DAYS_EMPLOYED': -3039.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 18.0,
#   'DAYS_ID_PUBLISH': -2437,
#   'INCOME_CREDIT_PERC': 0.2199,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -12.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -9833.0,
#   'DAYS_EMPLOYED_PERC': 0.1599052880820836,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 312682.5,
#   'PREV_CNT_PAYMENT_MEAN': 23.0,
#   'AMT_GOODS_PRICE': 297000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1007153.415,
#   'REGION_POPULATION_RELATIVE': 0.008019,
#   'INSTAL_DBD_SUM': 310.0,
#   'DAYS_LAST_PHONE_CHANGE': -617.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -181.0,
#   'POS_MONTHS_BALANCE_SIZE': 21.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 2482.92,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 77.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100007: {'PAYMENT_RATE': 0.0426228070175438,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.3227382869704046,
#   'DAYS_BIRTH': 19932,
#   'AMT_ANNUITY': 21865.5,
#   'DAYS_EMPLOYED': -3038.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 20.666666666666668,
#   'DAYS_ID_PUBLISH': -3458,
#   'INCOME_CREDIT_PERC': 0.1799629629629629,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -14.0,
#   'INSTAL_DPD_MEAN': 0.9545454545454546,
#   'DAYS_REGISTRATION': -4311.0,
#   'DAYS_EMPLOYED_PERC': 0.1524182219546458,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 513000.0,
#   'PREV_CNT_PAYMENT_MEAN': 20.666666666666668,
#   'AMT_GOODS_PRICE': 513000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 806127.975,
#   'REGION_POPULATION_RELATIVE': 0.028663,
#   'INSTAL_DBD_SUM': 303.0,
#   'DAYS_LAST_PHONE_CHANGE': -1106.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -1149.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -783.0,
#   'APPROVED_DAYS_DECISION_MAX': -374.0,
#   'POS_MONTHS_BALANCE_SIZE': 66.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -1149.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -783.0,
#   'INSTAL_AMT_PAYMENT_MIN': 0.18,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 31.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 146250.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100008: {'PAYMENT_RATE': 0.0561014321232304,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.6212263380626669,
#   'EXT_SOURCE_2': 0.3542247319929012,
#   'DAYS_BIRTH': 16941,
#   'AMT_ANNUITY': 27517.5,
#   'DAYS_EMPLOYED': -1588.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 14.0,
#   'DAYS_ID_PUBLISH': -477,
#   'INCOME_CREDIT_PERC': 0.2779545454545454,
#   'ACTIVE_DAYS_CREDIT_MAX': -78.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -82.0,
#   'INSTAL_DPD_MEAN': 37.62857142857143,
#   'DAYS_REGISTRATION': -4970.0,
#   'DAYS_EMPLOYED_PERC': 0.0937370875391063,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 471.0,
#   'AMT_CREDIT': 490495.5,
#   'PREV_CNT_PAYMENT_MEAN': 14.0,
#   'AMT_GOODS_PRICE': 454500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 957617.595,
#   'REGION_POPULATION_RELATIVE': 0.035792,
#   'INSTAL_DBD_SUM': 403.0,
#   'DAYS_LAST_PHONE_CHANGE': -2536.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -1097.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -792.0,
#   'APPROVED_DAYS_DECISION_MAX': -370.0,
#   'POS_MONTHS_BALANCE_SIZE': 83.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 267606.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -16.0,
#   'BURO_DAYS_CREDIT_MAX': -78.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 471.0,
#   'INSTAL_AMT_PAYMENT_MIN': 227.16,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 471.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -78.0,
#   'INSTAL_DBD_MAX': 28.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 100419.75,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 80019.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 471.0},
#  100009: {'PAYMENT_RATE': 0.0264626846736711,
#   'EXT_SOURCE_1': 0.7747614130547695,
#   'EXT_SOURCE_3': 0.4920600938649263,
#   'EXT_SOURCE_2': 0.7239998516953141,
#   'DAYS_BIRTH': 13778,
#   'AMT_ANNUITY': 41301.0,
#   'DAYS_EMPLOYED': -3130.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 8.0,
#   'DAYS_ID_PUBLISH': -619,
#   'INCOME_CREDIT_PERC': 0.2415263157894736,
#   'ACTIVE_DAYS_CREDIT_MAX': -239.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -58.0,
#   'INSTAL_DPD_MEAN': 0.1372549019607843,
#   'DAYS_REGISTRATION': -1213.0,
#   'DAYS_EMPLOYED_PERC': 0.2271737552620119,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -209.0,
#   'AMT_CREDIT': 1560726.0,
#   'PREV_CNT_PAYMENT_MEAN': 8.0,
#   'AMT_GOODS_PRICE': 1395000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 487995.12,
#   'REGION_POPULATION_RELATIVE': 0.035792,
#   'INSTAL_DBD_SUM': 445.0,
#   'DAYS_LAST_PHONE_CHANGE': -1562.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -684.0,
#   'OWN_CAR_AGE': 17.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 1044.0,
#   'APPROVED_DAYS_DECISION_MAX': -74.0,
#   'POS_MONTHS_BALANCE_SIZE': 64.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 1527561.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -245.75,
#   'BURO_DAYS_CREDIT_MAX': -239.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1402.0,
#   'INSTAL_AMT_PAYMENT_MIN': 6155.28,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1402.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -591.75,
#   'INSTAL_DBD_MAX': 23.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 233803.6071428572,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 76953.53571428571,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 596.5},
#  100010: {'PAYMENT_RATE': 0.0275,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.5406544504453575,
#   'EXT_SOURCE_2': 0.7142792864482229,
#   'DAYS_BIRTH': 18850,
#   'AMT_ANNUITY': 42075.0,
#   'DAYS_EMPLOYED': -449.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -2379,
#   'INCOME_CREDIT_PERC': 0.116875,
#   'ACTIVE_DAYS_CREDIT_MAX': -1138.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -774.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -4597.0,
#   'DAYS_EMPLOYED_PERC': 0.0238196286472148,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 689.0,
#   'AMT_CREDIT': 1530000.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 1530000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 274492.08,
#   'REGION_POPULATION_RELATIVE': 0.0031219999999999,
#   'INSTAL_DBD_SUM': 119.0,
#   'DAYS_LAST_PHONE_CHANGE': -1070.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -2741.0,
#   'OWN_CAR_AGE': 8.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -928.0,
#   'APPROVED_DAYS_DECISION_MAX': -1070.0,
#   'POS_MONTHS_BALANCE_SIZE': 11.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 675000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -18.0,
#   'BURO_DAYS_CREDIT_MAX': -1138.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 689.0,
#   'INSTAL_AMT_PAYMENT_MIN': 27321.39,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 689.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -1138.0,
#   'INSTAL_DBD_MAX': 30.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 315000.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 174003.75,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 689.0},
#  100011: {'PAYMENT_RATE': 0.0331759202047841,
#   'EXT_SOURCE_1': 0.5873340468730377,
#   'EXT_SOURCE_3': 0.7517237147741489,
#   'EXT_SOURCE_2': 0.2057472880073281,
#   'DAYS_BIRTH': 20099,
#   'AMT_ANNUITY': 33826.5,
#   'DAYS_EMPLOYED': nan,
#   'APPROVED_CNT_PAYMENT_MEAN': 14.0,
#   'DAYS_ID_PUBLISH': -3514,
#   'INCOME_CREDIT_PERC': 0.30068,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -37.0,
#   'INSTAL_DPD_MEAN': 7.946153846153846,
#   'DAYS_REGISTRATION': -7427.0,
#   'DAYS_EMPLOYED_PERC': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 1019610.0,
#   'PREV_CNT_PAYMENT_MEAN': 14.0,
#   'AMT_GOODS_PRICE': 913500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1472756.175,
#   'REGION_POPULATION_RELATIVE': 0.018634,
#   'INSTAL_DBD_SUM': 625.0,
#   'DAYS_LAST_PHONE_CHANGE': 0.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 5073.615,
#   'CLOSED_DAYS_CREDIT_MAX': -1309.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -860.0,
#   'APPROVED_DAYS_DECISION_MAX': -1189.0,
#   'POS_MONTHS_BALANCE_SIZE': 75.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -1309.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -860.0,
#   'INSTAL_AMT_PAYMENT_MIN': 449.685,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 32.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 108807.075,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100012: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.7466436294590924,
#   'DAYS_BIRTH': 14469,
#   'AMT_ANNUITY': 20250.0,
#   'DAYS_EMPLOYED': -2019.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 18.0,
#   'DAYS_ID_PUBLISH': -3992,
#   'INCOME_CREDIT_PERC': 0.15,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -151.0,
#   'INSTAL_DPD_MEAN': 0.5625,
#   'DAYS_REGISTRATION': -14437.0,
#   'DAYS_EMPLOYED_PERC': 0.1395397055774414,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 405000.0,
#   'PREV_CNT_PAYMENT_MEAN': 18.0,
#   'AMT_GOODS_PRICE': 405000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 501661.71,
#   'REGION_POPULATION_RELATIVE': 0.0196889999999999,
#   'INSTAL_DBD_SUM': 1242.0,
#   'DAYS_LAST_PHONE_CHANGE': -1673.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -507.0,
#   'POS_MONTHS_BALANCE_SIZE': 46.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 5.85,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 90.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100014: {'PAYMENT_RATE': 0.0324551724137931,
#   'EXT_SOURCE_1': 0.3197601716755032,
#   'EXT_SOURCE_3': 0.363945238612397,
#   'EXT_SOURCE_2': 0.6518623334244781,
#   'DAYS_BIRTH': 10197,
#   'AMT_ANNUITY': 21177.0,
#   'DAYS_EMPLOYED': -679.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 9.0,
#   'DAYS_ID_PUBLISH': -738,
#   'INCOME_CREDIT_PERC': 0.18824,
#   'ACTIVE_DAYS_CREDIT_MAX': -376.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -36.0,
#   'INSTAL_DPD_MEAN': 1.0526315789473684,
#   'DAYS_REGISTRATION': -4427.0,
#   'DAYS_EMPLOYED_PERC': 0.0665882122192801,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 704.0,
#   'AMT_CREDIT': 652500.0,
#   'PREV_CNT_PAYMENT_MEAN': 9.0,
#   'AMT_GOODS_PRICE': 652500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 166880.745,
#   'REGION_POPULATION_RELATIVE': 0.0228,
#   'INSTAL_DBD_SUM': 176.0,
#   'DAYS_LAST_PHONE_CHANGE': -844.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 3726.3525,
#   'CLOSED_DAYS_CREDIT_MAX': -435.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 45.0,
#   'APPROVED_DAYS_DECISION_MAX': -102.0,
#   'POS_MONTHS_BALANCE_SIZE': 16.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 1005750.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -29.5,
#   'BURO_DAYS_CREDIT_MAX': -376.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 723.0,
#   'INSTAL_AMT_PAYMENT_MIN': 530.1,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 723.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -399.5,
#   'INSTAL_DBD_MAX': 30.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 287363.7375,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 151642.8,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 713.5},
#  100015: {'PAYMENT_RATE': 0.0719745222929936,
#   'EXT_SOURCE_1': 0.7220444501416448,
#   'EXT_SOURCE_3': 0.6528965519806539,
#   'EXT_SOURCE_2': 0.5551831615131809,
#   'DAYS_BIRTH': 20417,
#   'AMT_ANNUITY': 10678.5,
#   'DAYS_EMPLOYED': nan,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -2512,
#   'INCOME_CREDIT_PERC': 0.2779472895746926,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -2108.0,
#   'INSTAL_DPD_MEAN': 2.1,
#   'DAYS_REGISTRATION': -5246.0,
#   'DAYS_EMPLOYED_PERC': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 148365.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 135000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 76586.805,
#   'REGION_POPULATION_RELATIVE': 0.015221,
#   'INSTAL_DBD_SUM': 150.0,
#   'DAYS_LAST_PHONE_CHANGE': -2396.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -319.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -16.0,
#   'APPROVED_DAYS_DECISION_MAX': -2396.0,
#   'POS_MONTHS_BALANCE_SIZE': 11.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -319.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -16.0,
#   'INSTAL_AMT_PAYMENT_MIN': 7584.525,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 29.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 102373.875,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100016: {'PAYMENT_RATE': 0.0727323316638842,
#   'EXT_SOURCE_1': 0.4648311169632833,
#   'EXT_SOURCE_3': 0.1766525794312139,
#   'EXT_SOURCE_2': 0.7150418188660659,
#   'DAYS_BIRTH': 13439,
#   'AMT_ANNUITY': 5881.5,
#   'DAYS_EMPLOYED': -2717.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 17.0,
#   'DAYS_ID_PUBLISH': -3227,
#   'INCOME_CREDIT_PERC': 0.0871333333333333,
#   'ACTIVE_DAYS_CREDIT_MAX': -128.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -539.0,
#   'INSTAL_DPD_MEAN': 3.527027027027027,
#   'DAYS_REGISTRATION': -311.0,
#   'DAYS_EMPLOYED_PERC': 0.2021727807128506,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 223.0,
#   'AMT_CREDIT': 80865.0,
#   'PREV_CNT_PAYMENT_MEAN': 17.0,
#   'AMT_GOODS_PRICE': 67500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 620981.82,
#   'REGION_POPULATION_RELATIVE': 0.031329,
#   'INSTAL_DBD_SUM': 363.0,
#   'DAYS_LAST_PHONE_CHANGE': -2370.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -528.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -347.0,
#   'APPROVED_DAYS_DECISION_MAX': -1049.0,
#   'POS_MONTHS_BALANCE_SIZE': 67.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 336757.5,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -15.0,
#   'BURO_DAYS_CREDIT_MAX': -128.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 845.0,
#   'INSTAL_AMT_PAYMENT_MIN': 3.96,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 845.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -168.25,
#   'INSTAL_DBD_MAX': 16.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 46075.5,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 12744.9,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 381.75},
#  100017: {'PAYMENT_RATE': 0.0315378434523576,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.7700870700124128,
#   'EXT_SOURCE_2': 0.5669066132460429,
#   'DAYS_BIRTH': 14086,
#   'AMT_ANNUITY': 28966.5,
#   'DAYS_EMPLOYED': -3028.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 17.0,
#   'DAYS_ID_PUBLISH': -4911,
#   'INCOME_CREDIT_PERC': 0.12874,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -21.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -643.0,
#   'DAYS_EMPLOYED_PERC': 0.2149652136873491,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 918468.0,
#   'PREV_CNT_PAYMENT_MEAN': 17.0,
#   'AMT_GOODS_PRICE': 697500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 405267.615,
#   'REGION_POPULATION_RELATIVE': 0.016612,
#   'INSTAL_DBD_SUM': 326.0,
#   'DAYS_LAST_PHONE_CHANGE': -4.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -909.0,
#   'OWN_CAR_AGE': 23.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 197.0,
#   'APPROVED_DAYS_DECISION_MAX': -612.0,
#   'POS_MONTHS_BALANCE_SIZE': 31.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -909.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 197.0,
#   'INSTAL_AMT_PAYMENT_MIN': 11783.52,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 24.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 143295.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100018: {'PAYMENT_RATE': 0.0423663256344188,
#   'EXT_SOURCE_1': 0.7219397686622343,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6426562048311103,
#   'DAYS_BIRTH': 14583,
#   'AMT_ANNUITY': 32778.0,
#   'DAYS_EMPLOYED': -203.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -2056,
#   'INCOME_CREDIT_PERC': 0.1734285714285714,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -40.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -615.0,
#   'DAYS_EMPLOYED_PERC': 0.0139203181787012,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 773680.5,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 679500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1178751.42,
#   'REGION_POPULATION_RELATIVE': 0.010006,
#   'INSTAL_DBD_SUM': 165.0,
#   'DAYS_LAST_PHONE_CHANGE': -188.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -188.0,
#   'POS_MONTHS_BALANCE_SIZE': 25.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 4109.265,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 21.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100019: {'PAYMENT_RATE': 0.0672511108442416,
#   'EXT_SOURCE_1': 0.1156343372622997,
#   'EXT_SOURCE_3': 0.6785676886853644,
#   'EXT_SOURCE_2': 0.34663398139668,
#   'DAYS_BIRTH': 8728,
#   'AMT_ANNUITY': 20160.0,
#   'DAYS_EMPLOYED': -1157.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 12.0,
#   'DAYS_ID_PUBLISH': -1368,
#   'INCOME_CREDIT_PERC': 0.128,
#   'ACTIVE_DAYS_CREDIT_MAX': -495.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -716.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -3494.0,
#   'DAYS_EMPLOYED_PERC': 0.1325618698441796,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 419.0,
#   'AMT_CREDIT': 299772.0,
#   'PREV_CNT_PAYMENT_MEAN': 12.0,
#   'AMT_GOODS_PRICE': 247500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 165093.03,
#   'REGION_POPULATION_RELATIVE': 0.020713,
#   'INSTAL_DBD_SUM': 244.0,
#   'DAYS_LAST_PHONE_CHANGE': -925.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 17.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -925.0,
#   'POS_MONTHS_BALANCE_SIZE': 8.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 720000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -26.5,
#   'BURO_DAYS_CREDIT_MAX': -495.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 10463.0,
#   'INSTAL_AMT_PAYMENT_MIN': 10518.615,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 10463.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -495.0,
#   'INSTAL_DBD_MAX': 66.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 122735.07,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 5441.0},
#  100020: {'PAYMENT_RATE': 0.0513135237758841,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.0621030378372968,
#   'EXT_SOURCE_2': 0.2363778398884225,
#   'DAYS_BIRTH': 12931,
#   'AMT_ANNUITY': 26149.5,
#   'DAYS_EMPLOYED': -1317.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 7.0,
#   'DAYS_ID_PUBLISH': -3866,
#   'INCOME_CREDIT_PERC': 0.242125,
#   'ACTIVE_DAYS_CREDIT_MAX': -90.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -35.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -6392.0,
#   'DAYS_EMPLOYED_PERC': 0.1018482715953909,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 8.0,
#   'AMT_CREDIT': 509602.5,
#   'PREV_CNT_PAYMENT_MEAN': 7.0,
#   'AMT_GOODS_PRICE': 387000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 92780.46,
#   'REGION_POPULATION_RELATIVE': 0.018634,
#   'INSTAL_DBD_SUM': 112.0,
#   'DAYS_LAST_PHONE_CHANGE': -3.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -288.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -104.0,
#   'APPROVED_DAYS_DECISION_MAX': -243.0,
#   'POS_MONTHS_BALANCE_SIZE': 14.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 151200.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -40.0,
#   'BURO_DAYS_CREDIT_MAX': -90.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 277.0,
#   'INSTAL_AMT_PAYMENT_MIN': 5729.265,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 277.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -133.0,
#   'INSTAL_DBD_MAX': 18.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 24142.5,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 30772.125,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 142.5},
#  100021: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6835133461914255,
#   'DAYS_BIRTH': 9776,
#   'AMT_ANNUITY': 13500.0,
#   'DAYS_EMPLOYED': -191.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 7.0,
#   'DAYS_ID_PUBLISH': -2427,
#   'INCOME_CREDIT_PERC': 0.1666666666666666,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -66.0,
#   'INSTAL_DPD_MEAN': 2.4347826086956523,
#   'DAYS_REGISTRATION': -4143.0,
#   'DAYS_EMPLOYED_PERC': 0.0195376432078559,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 270000.0,
#   'PREV_CNT_PAYMENT_MEAN': 7.0,
#   'AMT_GOODS_PRICE': 270000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 208357.515,
#   'REGION_POPULATION_RELATIVE': 0.010966,
#   'INSTAL_DBD_SUM': 339.0,
#   'DAYS_LAST_PHONE_CHANGE': -2811.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -261.0,
#   'POS_MONTHS_BALANCE_SIZE': 27.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 2705.76,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 46.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100022: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.5567274263630174,
#   'EXT_SOURCE_2': 0.7064284028871654,
#   'DAYS_BIRTH': 17718,
#   'AMT_ANNUITY': 7875.0,
#   'DAYS_EMPLOYED': -7804.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 18.0,
#   'DAYS_ID_PUBLISH': -1259,
#   'INCOME_CREDIT_PERC': 0.07,
#   'ACTIVE_DAYS_CREDIT_MAX': -289.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -51.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -8751.0,
#   'DAYS_EMPLOYED_PERC': 0.440456033412349,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 441.0,
#   'AMT_CREDIT': 157500.0,
#   'PREV_CNT_PAYMENT_MEAN': 18.0,
#   'AMT_GOODS_PRICE': 157500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 47361.825,
#   'REGION_POPULATION_RELATIVE': 0.04622,
#   'INSTAL_DBD_SUM': 164.0,
#   'DAYS_LAST_PHONE_CHANGE': -239.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -239.0,
#   'POS_MONTHS_BALANCE_SIZE': 7.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 1057500.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -28.0,
#   'BURO_DAYS_CREDIT_MAX': -289.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1439.0,
#   'INSTAL_AMT_PAYMENT_MIN': 6765.975,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1439.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -337.0,
#   'INSTAL_DBD_MAX': 27.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 205276.5,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 940.0},
#  100023: {'PAYMENT_RATE': 0.0322567315162234,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.4776491548517548,
#   'EXT_SOURCE_2': 0.5866171400119664,
#   'DAYS_BIRTH': 11348,
#   'AMT_ANNUITY': 17563.5,
#   'DAYS_EMPLOYED': -2038.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 12.5,
#   'DAYS_ID_PUBLISH': -3964,
#   'INCOME_CREDIT_PERC': 0.19515,
#   'ACTIVE_DAYS_CREDIT_MAX': -157.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -166.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -1021.0,
#   'DAYS_EMPLOYED_PERC': 0.1795911173775114,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -1250.0,
#   'AMT_CREDIT': 544491.0,
#   'PREV_CNT_PAYMENT_MEAN': 12.5,
#   'AMT_GOODS_PRICE': 454500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 493547.085,
#   'REGION_POPULATION_RELATIVE': 0.015221,
#   'INSTAL_DBD_SUM': 407.0,
#   'DAYS_LAST_PHONE_CHANGE': -1850.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 2720.85,
#   'CLOSED_DAYS_CREDIT_MAX': -508.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 1318.0,
#   'APPROVED_DAYS_DECISION_MAX': -262.0,
#   'POS_MONTHS_BALANCE_SIZE': 29.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 657715.5,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -177.0,
#   'BURO_DAYS_CREDIT_MAX': -157.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1669.0,
#   'INSTAL_AMT_PAYMENT_MIN': 7992.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1669.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -1141.25,
#   'INSTAL_DBD_MAX': 43.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 109775.205,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 13703.85,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 313.0},
#  100024: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': 0.5656548824667073,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.113374512719927,
#   'DAYS_BIRTH': 18252,
#   'AMT_ANNUITY': 21375.0,
#   'DAYS_EMPLOYED': -4286.0,
#   'APPROVED_CNT_PAYMENT_MEAN': nan,
#   'DAYS_ID_PUBLISH': -1800,
#   'INCOME_CREDIT_PERC': 0.1583333333333333,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': nan,
#   'INSTAL_DPD_MEAN': nan,
#   'DAYS_REGISTRATION': -298.0,
#   'DAYS_EMPLOYED_PERC': 0.2348235809774271,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 427500.0,
#   'PREV_CNT_PAYMENT_MEAN': nan,
#   'AMT_GOODS_PRICE': 427500.0,
#   'INSTAL_AMT_PAYMENT_SUM': nan,
#   'REGION_POPULATION_RELATIVE': 0.015221,
#   'INSTAL_DBD_SUM': nan,
#   'DAYS_LAST_PHONE_CHANGE': -296.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 7.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': nan,
#   'POS_MONTHS_BALANCE_SIZE': nan,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': nan,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100025: {'PAYMENT_RATE': 0.0331647350039533,
#   'EXT_SOURCE_1': 0.4377090198475417,
#   'EXT_SOURCE_3': 0.5424451438613613,
#   'EXT_SOURCE_2': 0.2337669575081463,
#   'DAYS_BIRTH': 14815,
#   'AMT_ANNUITY': 37561.5,
#   'DAYS_EMPLOYED': -1652.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 13.714285714285714,
#   'DAYS_ID_PUBLISH': -2299,
#   'INCOME_CREDIT_PERC': 0.1854888888888889,
#   'ACTIVE_DAYS_CREDIT_MAX': -700.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -697.0,
#   'INSTAL_DPD_MEAN': 1.565217391304348,
#   'DAYS_REGISTRATION': -2299.0,
#   'DAYS_EMPLOYED_PERC': 0.1115086061424232,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 1124.0,
#   'AMT_CREDIT': 1132573.5,
#   'PREV_CNT_PAYMENT_MEAN': 13.714285714285714,
#   'AMT_GOODS_PRICE': 927000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1442496.33,
#   'REGION_POPULATION_RELATIVE': 0.025164,
#   'INSTAL_DBD_SUM': 536.0,
#   'DAYS_LAST_PHONE_CHANGE': 0.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 14.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -7.0,
#   'POS_MONTHS_BALANCE_SIZE': 40.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 2452500.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -49.0,
#   'BURO_DAYS_CREDIT_MAX': -700.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1124.0,
#   'INSTAL_AMT_PAYMENT_MIN': 2.925,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1124.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -700.0,
#   'INSTAL_DBD_MAX': 35.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 1886544.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 1124.0},
#  100026: {'PAYMENT_RATE': 0.0653672214182344,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.3589512285783967,
#   'EXT_SOURCE_2': 0.457142971588935,
#   'DAYS_BIRTH': 11146,
#   'AMT_ANNUITY': 32521.5,
#   'DAYS_EMPLOYED': -4306.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 21.0,
#   'DAYS_ID_PUBLISH': -2518,
#   'INCOME_CREDIT_PERC': 0.07227,
#   'ACTIVE_DAYS_CREDIT_MAX': -148.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -425.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -114.0,
#   'DAYS_EMPLOYED_PERC': 0.3863269334290328,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 217.0,
#   'AMT_CREDIT': 497520.0,
#   'PREV_CNT_PAYMENT_MEAN': 21.0,
#   'AMT_GOODS_PRICE': 450000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 954356.76,
#   'REGION_POPULATION_RELATIVE': 0.020713,
#   'INSTAL_DBD_SUM': 75.0,
#   'DAYS_LAST_PHONE_CHANGE': -468.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -1644.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -468.0,
#   'POS_MONTHS_BALANCE_SIZE': 11.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 4050000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -15.0,
#   'BURO_DAYS_CREDIT_MAX': -148.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1581.0,
#   'INSTAL_AMT_PAYMENT_MIN': 23531.175,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1581.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -196.5,
#   'INSTAL_DBD_MAX': 17.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 1575000.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 1738907.19,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 899.0},
#  100027: {'PAYMENT_RATE': 0.099437148217636,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.6690566947824041,
#   'EXT_SOURCE_2': 0.6243047373592765,
#   'DAYS_BIRTH': 24827,
#   'AMT_ANNUITY': 23850.0,
#   'DAYS_EMPLOYED': nan,
#   'APPROVED_CNT_PAYMENT_MEAN': 11.0,
#   'DAYS_ID_PUBLISH': -3684,
#   'INCOME_CREDIT_PERC': 0.2864864864864865,
#   'ACTIVE_DAYS_CREDIT_MAX': -143.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -116.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -9012.0,
#   'DAYS_EMPLOYED_PERC': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 944.0,
#   'AMT_CREDIT': 239850.0,
#   'PREV_CNT_PAYMENT_MEAN': 11.333333333333334,
#   'AMT_GOODS_PRICE': 225000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 539424.36,
#   'REGION_POPULATION_RELATIVE': 0.006296,
#   'INSTAL_DBD_SUM': 210.0,
#   'DAYS_LAST_PHONE_CHANGE': -795.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 2565.0,
#   'CLOSED_DAYS_CREDIT_MAX': -253.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -130.0,
#   'APPROVED_DAYS_DECISION_MAX': -471.0,
#   'POS_MONTHS_BALANCE_SIZE': 23.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 427500.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -3.0,
#   'BURO_DAYS_CREDIT_MAX': -143.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 944.0,
#   'INSTAL_AMT_PAYMENT_MIN': 21553.74,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 944.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -143.0,
#   'INSTAL_DBD_MAX': 23.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 98898.75,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 125571.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 944.0},
#  100029: {'PAYMENT_RATE': 0.0513272727272727,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.5656079814115492,
#   'EXT_SOURCE_2': 0.7861793090532118,
#   'DAYS_BIRTH': 11286,
#   'AMT_ANNUITY': 12703.5,
#   'DAYS_EMPLOYED': -746.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -3729,
#   'INCOME_CREDIT_PERC': 0.0941,
#   'ACTIVE_DAYS_CREDIT_MAX': -110.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -224.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -108.0,
#   'DAYS_EMPLOYED_PERC': 0.0660995924153819,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 247500.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 247500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 135668.385,
#   'REGION_POPULATION_RELATIVE': 0.026392,
#   'INSTAL_DBD_SUM': 79.0,
#   'DAYS_LAST_PHONE_CHANGE': -4.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -1375.0,
#   'OWN_CAR_AGE': 7.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 1563.0,
#   'APPROVED_DAYS_DECISION_MAX': -324.0,
#   'POS_MONTHS_BALANCE_SIZE': 6.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 3735000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -17.0,
#   'BURO_DAYS_CREDIT_MAX': -110.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1563.0,
#   'INSTAL_AMT_PAYMENT_MIN': 22891.68,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': -110.0,
#   'INSTAL_DBD_MAX': 23.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 1231011.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 1227429.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100030: {'PAYMENT_RATE': 0.04922,
#   'EXT_SOURCE_1': 0.5619484093041138,
#   'EXT_SOURCE_3': 0.4614823912998385,
#   'EXT_SOURCE_2': 0.6514056365297631,
#   'DAYS_BIRTH': 19334,
#   'AMT_ANNUITY': 11074.5,
#   'DAYS_EMPLOYED': -3494.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 5.0,
#   'DAYS_ID_PUBLISH': -2893,
#   'INCOME_CREDIT_PERC': 0.12305,
#   'ACTIVE_DAYS_CREDIT_MAX': -418.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -233.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -2419.0,
#   'DAYS_EMPLOYED_PERC': 0.1807179062790938,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 1409.0,
#   'AMT_CREDIT': 225000.0,
#   'PREV_CNT_PAYMENT_MEAN': 8.625,
#   'AMT_GOODS_PRICE': 225000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 70923.87,
#   'REGION_POPULATION_RELATIVE': 0.028663,
#   'INSTAL_DBD_SUM': 131.0,
#   'DAYS_LAST_PHONE_CHANGE': 0.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -462.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 238.0,
#   'APPROVED_DAYS_DECISION_MAX': -378.0,
#   'POS_MONTHS_BALANCE_SIZE': 14.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 553500.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -14.0,
#   'BURO_DAYS_CREDIT_MAX': -418.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1409.0,
#   'INSTAL_AMT_PAYMENT_MIN': 9035.685,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1409.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -735.5,
#   'INSTAL_DBD_MAX': 35.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 22482.7425,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 75273.75,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 1409.0},
#  100031: {'PAYMENT_RATE': 0.0276293071780177,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.190705947811054,
#   'EXT_SOURCE_2': 0.5484771599678789,
#   'DAYS_BIRTH': 18724,
#   'AMT_ANNUITY': 27076.5,
#   'DAYS_EMPLOYED': -2628.0,
#   'APPROVED_CNT_PAYMENT_MEAN': nan,
#   'DAYS_ID_PUBLISH': -1827,
#   'INCOME_CREDIT_PERC': 0.24068,
#   'ACTIVE_DAYS_CREDIT_MAX': -75.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': nan,
#   'INSTAL_DPD_MEAN': nan,
#   'DAYS_REGISTRATION': -6573.0,
#   'DAYS_EMPLOYED_PERC': 0.1403546250801111,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 1021.0,
#   'AMT_CREDIT': 979992.0,
#   'PREV_CNT_PAYMENT_MEAN': nan,
#   'AMT_GOODS_PRICE': 702000.0,
#   'INSTAL_AMT_PAYMENT_SUM': nan,
#   'REGION_POPULATION_RELATIVE': 0.018029,
#   'INSTAL_DBD_SUM': nan,
#   'DAYS_LAST_PHONE_CHANGE': -161.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -203.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 960.0,
#   'APPROVED_DAYS_DECISION_MAX': nan,
#   'POS_MONTHS_BALANCE_SIZE': nan,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 751279.5,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -31.0,
#   'BURO_DAYS_CREDIT_MAX': -75.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1021.0,
#   'INSTAL_AMT_PAYMENT_MIN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1021.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -332.0,
#   'INSTAL_DBD_MAX': nan,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 804843.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 562500.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 1021.0},
#  100032: {'PAYMENT_RATE': 0.0728616248348745,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.6594055320683344,
#   'EXT_SOURCE_2': 0.5411237022695412,
#   'DAYS_BIRTH': 15948,
#   'AMT_ANNUITY': 23827.5,
#   'DAYS_EMPLOYED': -1234.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -3153,
#   'INCOME_CREDIT_PERC': 0.2118,
#   'ACTIVE_DAYS_CREDIT_MAX': -556.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -1307.0,
#   'INSTAL_DPD_MEAN': 1.2857142857142858,
#   'DAYS_REGISTRATION': -5782.0,
#   'DAYS_EMPLOYED_PERC': 0.0773764735390017,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -191.0,
#   'AMT_CREDIT': 327024.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 270000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 47463.03,
#   'REGION_POPULATION_RELATIVE': 0.019101,
#   'INSTAL_DBD_SUM': 330.0,
#   'DAYS_LAST_PHONE_CHANGE': -2.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -951.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -586.0,
#   'APPROVED_DAYS_DECISION_MAX': -1497.0,
#   'POS_MONTHS_BALANCE_SIZE': 7.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 209250.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -54.0,
#   'BURO_DAYS_CREDIT_MAX': -556.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -191.0,
#   'INSTAL_AMT_PAYMENT_MIN': 4.275,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': -191.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -556.0,
#   'INSTAL_DBD_MAX': 86.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 353970.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': -191.0},
#  100033: {'PAYMENT_RATE': 0.0729316035051781,
#   'EXT_SOURCE_1': 0.6003959050009468,
#   'EXT_SOURCE_3': 0.524496446363472,
#   'EXT_SOURCE_2': 0.6850109901296888,
#   'DAYS_BIRTH': 9994,
#   'AMT_ANNUITY': 57676.5,
#   'DAYS_EMPLOYED': -1796.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 12.0,
#   'DAYS_ID_PUBLISH': -2661,
#   'INCOME_CREDIT_PERC': 0.2136166666666666,
#   'ACTIVE_DAYS_CREDIT_MAX': -195.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -495.0,
#   'INSTAL_DPD_MEAN': 23.32258064516129,
#   'DAYS_REGISTRATION': -4668.0,
#   'DAYS_EMPLOYED_PERC': 0.1797078246948169,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 913.0,
#   'AMT_CREDIT': 790830.0,
#   'PREV_CNT_PAYMENT_MEAN': 12.0,
#   'AMT_GOODS_PRICE': 675000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 69411.645,
#   'REGION_POPULATION_RELATIVE': 0.04622,
#   'INSTAL_DBD_SUM': 196.0,
#   'DAYS_LAST_PHONE_CHANGE': -849.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 1.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -849.0,
#   'POS_MONTHS_BALANCE_SIZE': 13.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 675000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -169.0,
#   'BURO_DAYS_CREDIT_MAX': -195.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 913.0,
#   'INSTAL_AMT_PAYMENT_MIN': 1.08,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 913.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -195.0,
#   'INSTAL_DBD_MAX': 44.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 913.0},
#  100034: {'PAYMENT_RATE': 0.05,
#   'EXT_SOURCE_1': 0.2979135090150507,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.5027790378786304,
#   'DAYS_BIRTH': 10341,
#   'AMT_ANNUITY': 9000.0,
#   'DAYS_EMPLOYED': -1010.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -3015,
#   'INCOME_CREDIT_PERC': 0.1,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -189.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -4799.0,
#   'DAYS_EMPLOYED_PERC': 0.0976694710376172,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 180000.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 180000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 311355.765,
#   'REGION_POPULATION_RELATIVE': 0.030755,
#   'INSTAL_DBD_SUM': 190.0,
#   'DAYS_LAST_PHONE_CHANGE': -599.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -288.0,
#   'POS_MONTHS_BALANCE_SIZE': 11.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 13888.98,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 51.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100035: {'PAYMENT_RATE': 0.0369316645942585,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.4101025731788671,
#   'EXT_SOURCE_2': 0.479987342189869,
#   'DAYS_BIRTH': 15280,
#   'AMT_ANNUITY': 24592.5,
#   'DAYS_EMPLOYED': -2668.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 14.75,
#   'DAYS_ID_PUBLISH': -3787,
#   'INCOME_CREDIT_PERC': 0.084076923076923,
#   'ACTIVE_DAYS_CREDIT_MAX': -184.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -651.0,
#   'INSTAL_DPD_MEAN': 0.7746478873239436,
#   'DAYS_REGISTRATION': -5266.0,
#   'DAYS_EMPLOYED_PERC': 0.1746073298429319,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -152.0,
#   'AMT_CREDIT': 665892.0,
#   'PREV_CNT_PAYMENT_MEAN': 22.6,
#   'AMT_GOODS_PRICE': 477000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1979849.025,
#   'REGION_POPULATION_RELATIVE': 0.025164,
#   'INSTAL_DBD_SUM': 413.0,
#   'DAYS_LAST_PHONE_CHANGE': -1634.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 13760.06625,
#   'CLOSED_DAYS_CREDIT_MAX': -2159.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -1860.0,
#   'APPROVED_DAYS_DECISION_MAX': -723.0,
#   'POS_MONTHS_BALANCE_SIZE': 74.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 3218368.5,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -33.2,
#   'BURO_DAYS_CREDIT_MAX': -184.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 9980.0,
#   'INSTAL_AMT_PAYMENT_MIN': 2.475,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 9980.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -521.8,
#   'INSTAL_DBD_MAX': 30.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 81679.23,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 410874.3,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 2593.0},
#  100036: {'PAYMENT_RATE': 0.0488874437570303,
#   'EXT_SOURCE_1': 0.2744223724911185,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6273004007953609,
#   'DAYS_BIRTH': 11144,
#   'AMT_ANNUITY': 25033.5,
#   'DAYS_EMPLOYED': -1104.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -2904,
#   'INCOME_CREDIT_PERC': 0.22252,
#   'ACTIVE_DAYS_CREDIT_MAX': -889.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -39.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -7846.0,
#   'DAYS_EMPLOYED_PERC': 0.0990667623833453,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -462.0,
#   'AMT_CREDIT': 512064.0,
#   'PREV_CNT_PAYMENT_MEAN': 15.6,
#   'AMT_GOODS_PRICE': 360000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 78613.605,
#   'REGION_POPULATION_RELATIVE': 0.008575,
#   'INSTAL_DBD_SUM': 222.0,
#   'DAYS_LAST_PHONE_CHANGE': -397.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -397.0,
#   'POS_MONTHS_BALANCE_SIZE': 12.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 94959.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -519.0,
#   'BURO_DAYS_CREDIT_MAX': -889.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -462.0,
#   'INSTAL_AMT_PAYMENT_MIN': 6548.04,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': -462.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -889.0,
#   'INSTAL_DBD_MAX': 67.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 8339.355,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': -462.0},
#  100037: {'PAYMENT_RATE': 0.1049882416787264,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.7981372313187245,
#   'EXT_SOURCE_2': 0.5594667916353414,
#   'DAYS_BIRTH': 12974,
#   'AMT_ANNUITY': 20893.5,
#   'DAYS_EMPLOYED': -4404.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -4464,
#   'INCOME_CREDIT_PERC': 0.23215,
#   'ACTIVE_DAYS_CREDIT_MAX': -1467.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -235.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -7123.0,
#   'DAYS_EMPLOYED_PERC': 0.3394481270232773,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 199008.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.8,
#   'AMT_GOODS_PRICE': 180000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 422786.52,
#   'REGION_POPULATION_RELATIVE': 0.010032,
#   'INSTAL_DBD_SUM': 403.0,
#   'DAYS_LAST_PHONE_CHANGE': -2766.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -1247.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -1063.0,
#   'APPROVED_DAYS_DECISION_MAX': -539.0,
#   'POS_MONTHS_BALANCE_SIZE': 26.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 108000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -994.0,
#   'BURO_DAYS_CREDIT_MAX': -1247.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -1063.0,
#   'INSTAL_AMT_PAYMENT_MIN': 5305.995,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': -1467.0,
#   'INSTAL_DBD_MAX': 63.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 69161.78571428571,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100039: {'PAYMENT_RATE': 0.0532772046956596,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.4118485559242397,
#   'EXT_SOURCE_2': 0.3217448956617718,
#   'DAYS_BIRTH': 11694,
#   'AMT_ANNUITY': 39069.0,
#   'DAYS_EMPLOYED': -2060.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 18.0,
#   'DAYS_ID_PUBLISH': -3557,
#   'INCOME_CREDIT_PERC': 0.108525,
#   'ACTIVE_DAYS_CREDIT_MAX': -90.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -468.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -3557.0,
#   'DAYS_EMPLOYED_PERC': 0.1761587138703608,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 641.0,
#   'AMT_CREDIT': 733315.5,
#   'PREV_CNT_PAYMENT_MEAN': 18.0,
#   'AMT_GOODS_PRICE': 679500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 2305501.785,
#   'REGION_POPULATION_RELATIVE': 0.015221,
#   'INSTAL_DBD_SUM': 381.0,
#   'DAYS_LAST_PHONE_CHANGE': -697.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
# ...
#   'INSTAL_DBD_MAX': 37.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 96917.175,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 4102.5,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100104: {'PAYMENT_RATE': 0.0560707708497763,
#   'EXT_SOURCE_1': 0.7631370618175837,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6446273721560554,
#   'DAYS_BIRTH': 18556,
#   'AMT_ANNUITY': 30690.0,
#   'DAYS_EMPLOYED': -862.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -2045,
#   'INCOME_CREDIT_PERC': 0.341,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -2299.0,
#   'INSTAL_DPD_MEAN': 12.176470588235292,
#   'DAYS_REGISTRATION': -6769.0,
#   'DAYS_EMPLOYED_PERC': 0.0464539771502479,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 547344.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 472500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 29444.13,
#   'REGION_POPULATION_RELATIVE': 0.022625,
#   'INSTAL_DBD_SUM': 36.0,
#   'DAYS_LAST_PHONE_CHANGE': -2591.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -2283.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -457.0,
#   'APPROVED_DAYS_DECISION_MAX': -2591.0,
#   'POS_MONTHS_BALANCE_SIZE': 83.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -2283.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -457.0,
#   'INSTAL_AMT_PAYMENT_MIN': 32.67,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 9.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 765000.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100105: {'PAYMENT_RATE': 0.10558,
#   'EXT_SOURCE_1': 0.765153942091246,
#   'EXT_SOURCE_3': 0.4118485559242397,
#   'EXT_SOURCE_2': 0.2547599571469118,
#   'DAYS_BIRTH': 19810,
#   'AMT_ANNUITY': 23755.5,
#   'DAYS_EMPLOYED': -8862.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.166666666666667,
#   'DAYS_ID_PUBLISH': -3043,
#   'INCOME_CREDIT_PERC': 0.1227674418604651,
#   'ACTIVE_DAYS_CREDIT_MAX': -175.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -134.0,
#   'INSTAL_DPD_MEAN': 0.4383561643835616,
#   'DAYS_REGISTRATION': -4493.0,
#   'DAYS_EMPLOYED_PERC': 0.4473498233215547,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 7.0,
#   'AMT_CREDIT': 225000.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 225000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 1497246.885,
#   'REGION_POPULATION_RELATIVE': 0.031329,
#   'INSTAL_DBD_SUM': 571.0,
#   'DAYS_LAST_PHONE_CHANGE': -1733.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 3360.0,
#   'CLOSED_DAYS_CREDIT_MAX': -382.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -13.0,
#   'APPROVED_DAYS_DECISION_MAX': -321.0,
#   'POS_MONTHS_BALANCE_SIZE': 83.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 98454.42,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -19.0,
#   'BURO_DAYS_CREDIT_MAX': -175.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 7.0,
#   'INSTAL_AMT_PAYMENT_MIN': 211.41,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 7.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -175.0,
#   'INSTAL_DBD_MAX': 33.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 313036.2,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 3754.8,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 7.0},
#  100108: {'PAYMENT_RATE': 0.0574058784676354,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.6413682574954046,
#   'EXT_SOURCE_2': 0.7566679797246073,
#   'DAYS_BIRTH': 12780,
#   'AMT_ANNUITY': 31288.5,
#   'DAYS_EMPLOYED': -1415.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -870,
#   'INCOME_CREDIT_PERC': 0.1829736842105263,
#   'ACTIVE_DAYS_CREDIT_MAX': -982.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -371.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -5146.0,
#   'DAYS_EMPLOYED_PERC': 0.1107198748043818,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -302.0,
#   'AMT_CREDIT': 545040.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 450000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 151613.46,
#   'REGION_POPULATION_RELATIVE': 0.006629,
#   'INSTAL_DBD_SUM': 169.0,
#   'DAYS_LAST_PHONE_CHANGE': -546.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': -2519.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -2275.0,
#   'APPROVED_DAYS_DECISION_MAX': -546.0,
#   'POS_MONTHS_BALANCE_SIZE': 8.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 513000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -12.5,
#   'BURO_DAYS_CREDIT_MAX': -982.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -302.0,
#   'INSTAL_AMT_PAYMENT_MIN': 25265.16,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': -302.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -1610.0,
#   'INSTAL_DBD_MAX': 30.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 135661.5,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 20439.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': -302.0},
#  100110: {'PAYMENT_RATE': 0.0671731789676796,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.3280631605201915,
#   'EXT_SOURCE_2': 0.6405493008893001,
#   'DAYS_BIRTH': 10744,
#   'AMT_ANNUITY': 25065.0,
#   'DAYS_EMPLOYED': -741.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.5,
#   'DAYS_ID_PUBLISH': -2381,
#   'INCOME_CREDIT_PERC': 0.1856666666666666,
#   'ACTIVE_DAYS_CREDIT_MAX': -86.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -28.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -442.0,
#   'DAYS_EMPLOYED_PERC': 0.0689687267311988,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 218.0,
#   'AMT_CREDIT': 373140.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.5,
#   'AMT_GOODS_PRICE': 337500.0,
#   'INSTAL_AMT_PAYMENT_SUM': 98709.075,
#   'REGION_POPULATION_RELATIVE': 0.035792,
#   'INSTAL_DBD_SUM': 136.0,
#   'DAYS_LAST_PHONE_CHANGE': 0.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 0.0,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 21.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -59.0,
#   'POS_MONTHS_BALANCE_SIZE': 10.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 65511.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -20.0,
#   'BURO_DAYS_CREDIT_MAX': -86.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 218.0,
#   'INSTAL_AMT_PAYMENT_MIN': 8232.3,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 218.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -86.0,
#   'INSTAL_DBD_MAX': 29.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 52820.595,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 218.0},
#  100111: {'PAYMENT_RATE': 0.0324081803005008,
#   'EXT_SOURCE_1': 0.5633231337420023,
#   'EXT_SOURCE_3': 0.228883416700673,
#   'EXT_SOURCE_2': 0.608604105963283,
#   'DAYS_BIRTH': 10485,
#   'AMT_ANNUITY': 27954.0,
#   'DAYS_EMPLOYED': -1249.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 11.2,
#   'DAYS_ID_PUBLISH': -3110,
#   'INCOME_CREDIT_PERC': 0.24848,
#   'ACTIVE_DAYS_CREDIT_MAX': -277.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -508.0,
#   'INSTAL_DPD_MEAN': 0.3529411764705882,
#   'DAYS_REGISTRATION': -4628.0,
#   'DAYS_EMPLOYED_PERC': 0.1191225560324272,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 98.0,
#   'AMT_CREDIT': 862560.0,
#   'PREV_CNT_PAYMENT_MEAN': 11.0,
#   'AMT_GOODS_PRICE': 720000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 501427.755,
#   'REGION_POPULATION_RELATIVE': 0.0228,
#   'INSTAL_DBD_SUM': 556.0,
#   'DAYS_LAST_PHONE_CHANGE': -1234.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 4774.0,
#   'CLOSED_DAYS_CREDIT_MAX': -270.0,
#   'OWN_CAR_AGE': 17.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': 9233.0,
#   'APPROVED_DAYS_DECISION_MAX': -621.0,
#   'POS_MONTHS_BALANCE_SIZE': 37.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 322830.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -119.66666666666669,
#   'BURO_DAYS_CREDIT_MAX': -270.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 9233.0,
#   'INSTAL_AMT_PAYMENT_MIN': 1897.65,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 98.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -325.3333333333333,
#   'INSTAL_DBD_MAX': 85.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 242554.635,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 13009.03875,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 98.0},
#  100112: {'PAYMENT_RATE': 0.0672361714177836,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': 0.0774985464900651,
#   'EXT_SOURCE_2': 0.4323402118056743,
#   'DAYS_BIRTH': 10199,
#   'AMT_ANNUITY': 64107.0,
#   'DAYS_EMPLOYED': -2015.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 7.0,
#   'DAYS_ID_PUBLISH': -1038,
#   'INCOME_CREDIT_PERC': 0.2035142857142857,
#   'ACTIVE_DAYS_CREDIT_MAX': -271.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -118.0,
#   'INSTAL_DPD_MEAN': 0.05,
#   'DAYS_REGISTRATION': -4802.0,
#   'DAYS_EMPLOYED_PERC': 0.1975683890577507,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 793.0,
#   'AMT_CREDIT': 953460.0,
#   'PREV_CNT_PAYMENT_MEAN': 7.0,
#   'AMT_GOODS_PRICE': 900000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 382163.49,
#   'REGION_POPULATION_RELATIVE': 0.030755,
#   'INSTAL_DBD_SUM': 290.0,
#   'DAYS_LAST_PHONE_CHANGE': -591.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': 2.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -411.0,
#   'POS_MONTHS_BALANCE_SIZE': 21.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 130500.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -54.5,
#   'BURO_DAYS_CREDIT_MAX': -271.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 31070.0,
#   'INSTAL_AMT_PAYMENT_MIN': 4479.075,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 31070.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -288.0,
#   'INSTAL_DBD_MAX': 63.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 42824.25,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 15931.5},
#  100113: {'PAYMENT_RATE': 0.0496,
#   'EXT_SOURCE_1': 0.4757617930038634,
#   'EXT_SOURCE_3': 0.7898803468924867,
#   'EXT_SOURCE_2': 0.5930185238421518,
#   'DAYS_BIRTH': 15137,
#   'AMT_ANNUITY': 6696.0,
#   'DAYS_EMPLOYED': -7980.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 9.0,
#   'DAYS_ID_PUBLISH': -4576,
#   'INCOME_CREDIT_PERC': 0.0875294117647058,
#   'ACTIVE_DAYS_CREDIT_MAX': -753.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -54.0,
#   'INSTAL_DPD_MEAN': 21.23076923076923,
#   'DAYS_REGISTRATION': -9176.0,
#   'DAYS_EMPLOYED_PERC': 0.5271850432714541,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': 1026.0,
#   'AMT_CREDIT': 135000.0,
#   'PREV_CNT_PAYMENT_MEAN': 7.5,
#   'AMT_GOODS_PRICE': 135000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 60215.265,
#   'REGION_POPULATION_RELATIVE': 0.028663,
#   'INSTAL_DBD_SUM': 110.0,
#   'DAYS_LAST_PHONE_CHANGE': -1981.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': -1981.0,
#   'OWN_CAR_AGE': 11.0,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -1616.0,
#   'APPROVED_DAYS_DECISION_MAX': -194.0,
#   'POS_MONTHS_BALANCE_SIZE': 22.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 567000.0,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -10.0,
#   'BURO_DAYS_CREDIT_MAX': -753.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 1073.0,
#   'INSTAL_AMT_PAYMENT_MIN': 6.615,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 1073.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -776.5,
#   'INSTAL_DBD_MAX': 40.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 43722.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 133789.5,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 1049.5},
#  100114: {'PAYMENT_RATE': 0.0794620253164557,
#   'EXT_SOURCE_1': 0.3957242668511344,
#   'EXT_SOURCE_3': 0.2650494299443805,
#   'EXT_SOURCE_2': 0.1549370735653434,
#   'DAYS_BIRTH': 10734,
#   'AMT_ANNUITY': 22599.0,
#   'DAYS_EMPLOYED': -693.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 6.0,
#   'DAYS_ID_PUBLISH': -1362,
#   'INCOME_CREDIT_PERC': 0.1674,
#   'ACTIVE_DAYS_CREDIT_MAX': -648.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -18.0,
#   'INSTAL_DPD_MEAN': 1.3,
#   'DAYS_REGISTRATION': -7913.0,
#   'DAYS_EMPLOYED_PERC': 0.0645612073784237,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 284400.0,
#   'PREV_CNT_PAYMENT_MEAN': 6.0,
#   'AMT_GOODS_PRICE': 225000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 58283.82,
#   'REGION_POPULATION_RELATIVE': 0.030755,
#   'INSTAL_DBD_SUM': 85.0,
#   'DAYS_LAST_PHONE_CHANGE': -227.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 1658.4075,
#   'CLOSED_DAYS_CREDIT_MAX': -797.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -614.0,
#   'APPROVED_DAYS_DECISION_MAX': -227.0,
#   'POS_MONTHS_BALANCE_SIZE': 7.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 142445.88,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -53.5,
#   'BURO_DAYS_CREDIT_MAX': -648.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -614.0,
#   'INSTAL_AMT_PAYMENT_MIN': 444.96,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': -824.0,
#   'INSTAL_DBD_MAX': 30.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 45666.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 11408.625,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100115: {'PAYMENT_RATE': 0.0466142857142857,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.3343001962973505,
#   'DAYS_BIRTH': 15371,
#   'AMT_ANNUITY': 14683.5,
#   'DAYS_EMPLOYED': -367.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 3.0,
#   'DAYS_ID_PUBLISH': -4211,
#   'INCOME_CREDIT_PERC': 0.16315,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -23.0,
#   'INSTAL_DPD_MEAN': 0.0,
#   'DAYS_REGISTRATION': -3071.0,
#   'DAYS_EMPLOYED_PERC': 0.0238761303753822,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 315000.0,
#   'PREV_CNT_PAYMENT_MEAN': 3.0,
#   'AMT_GOODS_PRICE': 315000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 40895.685,
#   'REGION_POPULATION_RELATIVE': 0.028663,
#   'INSTAL_DBD_SUM': 65.0,
#   'DAYS_LAST_PHONE_CHANGE': -40.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 3420.0,
#   'CLOSED_DAYS_CREDIT_MAX': -2899.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -2687.0,
#   'APPROVED_DAYS_DECISION_MAX': -40.0,
#   'POS_MONTHS_BALANCE_SIZE': 7.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': -2899.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': -2687.0,
#   'INSTAL_AMT_PAYMENT_MIN': 4500.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 13.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 18513.0,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 0.0,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan},
#  100116: {'PAYMENT_RATE': 0.035575,
#   'EXT_SOURCE_1': 0.6712718925800566,
#   'EXT_SOURCE_3': 0.0710551246687366,
#   'EXT_SOURCE_2': 0.7002735745029195,
#   'DAYS_BIRTH': 14751,
#   'AMT_ANNUITY': 32017.5,
#   'DAYS_EMPLOYED': -6737.0,
#   'APPROVED_CNT_PAYMENT_MEAN': 11.2,
#   'DAYS_ID_PUBLISH': -4788,
#   'INCOME_CREDIT_PERC': 0.1317592592592592,
#   'ACTIVE_DAYS_CREDIT_MAX': -104.0,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -57.0,
#   'INSTAL_DPD_MEAN': 1.2123893805309736,
#   'DAYS_REGISTRATION': -3390.0,
#   'DAYS_EMPLOYED_PERC': 0.4567147989966782,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': -805.0,
#   'AMT_CREDIT': 900000.0,
#   'PREV_CNT_PAYMENT_MEAN': 17.666666666666668,
#   'AMT_GOODS_PRICE': 900000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 2684209.41,
#   'REGION_POPULATION_RELATIVE': 0.010006,
#   'INSTAL_DBD_SUM': 922.0,
#   'DAYS_LAST_PHONE_CHANGE': -1083.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': 14076.4275,
#   'CLOSED_DAYS_CREDIT_MAX': -614.0,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': -430.0,
#   'APPROVED_DAYS_DECISION_MAX': -264.0,
#   'POS_MONTHS_BALANCE_SIZE': 31.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': 4469011.875,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': -118.625,
#   'BURO_DAYS_CREDIT_MAX': -104.0,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': 31066.0,
#   'INSTAL_AMT_PAYMENT_MIN': 9.81,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': 31066.0,
#   'ACTIVE_DAYS_CREDIT_MEAN': -662.875,
#   'INSTAL_DBD_MAX': 95.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': 352153.525,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 142965.51882352942,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 4146.75},
#  100118: {'PAYMENT_RATE': 0.03932,
#   'EXT_SOURCE_1': nan,
#   'EXT_SOURCE_3': nan,
#   'EXT_SOURCE_2': 0.6263029188866104,
#   'DAYS_BIRTH': 22471,
#   'AMT_ANNUITY': 26541.0,
#   'DAYS_EMPLOYED': nan,
#   'APPROVED_CNT_PAYMENT_MEAN': 10.0,
#   'DAYS_ID_PUBLISH': -4323,
#   'INCOME_CREDIT_PERC': 0.2949,
#   'ACTIVE_DAYS_CREDIT_MAX': nan,
#   'INSTAL_DAYS_ENTRY_PAYMENT_MAX': -811.0,
#   'INSTAL_DPD_MEAN': 0.35,
#   'DAYS_REGISTRATION': -217.0,
#   'DAYS_EMPLOYED_PERC': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MIN': nan,
#   'AMT_CREDIT': 675000.0,
#   'PREV_CNT_PAYMENT_MEAN': 10.0,
#   'AMT_GOODS_PRICE': 675000.0,
#   'INSTAL_AMT_PAYMENT_SUM': 378937.44,
#   'REGION_POPULATION_RELATIVE': 0.026392,
#   'INSTAL_DBD_SUM': 119.0,
#   'DAYS_LAST_PHONE_CHANGE': 0.0,
#   'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN': nan,
#   'CLOSED_DAYS_CREDIT_MAX': nan,
#   'OWN_CAR_AGE': nan,
#   'CLOSED_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'APPROVED_DAYS_DECISION_MAX': -1105.0,
#   'POS_MONTHS_BALANCE_SIZE': 22.0,
#   'ACTIVE_AMT_CREDIT_SUM_SUM': nan,
#   'ACTIVE_DAYS_CREDIT_UPDATE_MEAN': nan,
#   'BURO_DAYS_CREDIT_MAX': nan,
#   'BURO_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'INSTAL_AMT_PAYMENT_MIN': 15233.175,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MAX': nan,
#   'ACTIVE_DAYS_CREDIT_MEAN': nan,
#   'INSTAL_DBD_MAX': 14.0,
#   'CLOSED_AMT_CREDIT_SUM_MEAN': nan,
#   'BURO_AMT_CREDIT_SUM_DEBT_MEAN': nan,
#   'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': nan}}

# %%
with open('api/backend/data/data.pkl', 'wb') as f:
    pickle.dump(df_api, f)

# %% [markdown]
# # Pipeline

# %%
with open('api/backend/data/data.pkl', 'rb') as f:
    fichier = pickle.load(f)
    
df_data = pd.DataFrame(pd.read_pickle('api/backend/data.pkl')).transpose()
# ---------------------- Pipeline

def cout_metier(y_test, pred_test_y):
    poids_tn = 1 # on maximise le nombre de personnes pouvant rembourser son prêt
    poids_fp = 0
    poids_fn = -10 # on veut à tout prix éviter les personnes ne remboursant pas le prêt que l'algorithme n'arrive pas à détecter
    poids_tp = 0
    conf_mat = confusion_matrix(y_test, pred_test_y)
    tn, fp, fn, tp = conf_mat.ravel()
    total = tn+fp+fn+tp
    
    return (tn*poids_tn + fp*poids_fp + fn*poids_fn + tp * poids_tp)/total


metric_custom = make_scorer(cout_metier)




url_pipeline = 'pipeline/pipeline_perso_random_iter50.pkl'
pipe = pickle.load(open(url_pipeline, 'rb'))

# %% [markdown]
# # Test Shap

# %%
import requests
import json

def collect_donnees(lien):
    # http://127.0.01:5000/ is from the flask api
    response = requests.get(lien)

    data_table = pd.DataFrame.from_dict(response.json(), orient="index")
    data_table = data_table.transpose()
    return data_table

# %%
# response = requests.get(f'https://kevin-oc-api.herokuapp.com/client/all/').json()
# response = np.asarray(json.loads(response))
# response

# %%
explainer = pickle.load(open('api/frontend/shap_model/explainer.pkl', 'rb'))
shap_values = pickle.load(open('api/frontend/shap_model/values.pkl', 'rb'))
expected_values = pickle.load(open('api/frontend/shap_model/expected_values.pkl', 'rb'))
shap_value_decision0 = pickle.load(open('api/frontend/shap_model/decision_plot0.pkl', 'rb'))
shap_value_decision1 = pickle.load(open('api/frontend/shap_model/decision_plot1.pkl', 'rb'))

# %%
# shap.initjs()
# df_shap = collect_donnees('https://kevin-oc-api.herokuapp.com/client/100002')
# df_shap.drop(['PROBABILITY'], axis=1, inplace=True)
# df_shap

# %%
# data = collect_donnees('https://kevin-oc-api.herokuapp.com/alldata/?remboursement=false').transpose()

# %%
def isNan(num):
    return num != num

# %%
metric_custom = make_scorer(cout_metier)

url_pipeline = './pipeline/pipeline_perso_random_iter50.pkl'
pipe = pickle.load(open(url_pipeline, 'rb'))
# pipe = pickle.load(open(url_pipeline, 'rb'))

# pipe.best_estimator_[0].transform utilisation d'iterativeimputer

def predict(dict):
    # si on a déjà predict, la valeur est retenue, donc :
    if len(dict) >= 41:
        del dict['PROBABILITY']
        
    df = pd.DataFrame.from_dict(dict, orient="index")
    df = df.transpose()
    df = df.replace('Indisp', None)
    proba = pipe.predict_proba(df)[:,1] # Probabilité de remboursement
    proba = round(np.array(proba)[0],2)
    return proba

# %%
def positive_nombre(x):
    if type(x) == int or type(x) == float:
        if x < 0:
            x = x * (-1) 
    return x

def collect_donnees(lien, shap:bool=False, client_connu:bool=True):

    if client_connu:
        response = requests.get(lien)
        data_table = pd.DataFrame.from_dict(response.json(), orient="index")
    else:
        data_table = pd.DataFrame.from_dict(lien, orient="index")

    
    data_table = data_table.transpose()
    
    # on transforme tous les nombres négatifs dans la data de départ en positif ... Ce sera plus lisible pour les graphiques.
    
    for col in ['DAYS_BIRTH', 'DAYS_ID_PUBLISH', 'DAYS_EMPLOYED']:
        try:
            data_table[col] = data_table[col].apply(positive_nombre)
        except KeyError:
            data_table = data_table.transpose()
            data_table[col] = data_table[col].apply(positive_nombre)
        
    if shap:
        data_table.drop(['PROBABILITY'], axis=1, inplace=True)
        
    return data_table

# %%
import requests
# data_avg_rembourse = collect_donnees('https://kevin-oc-api.herokuapp.com/client/client_avg/?remboursement=true')
# data_avg_no_rembourse = collect_donnees('https://kevin-oc-api.herokuapp.com/client/client_avg/?remboursement=false')
data_all_rembourse = collect_donnees('https://kevin-oc-api.herokuapp.com/alldata/?remboursement=true')
data_all_no_rembourse = collect_donnees('https://kevin-oc-api.herokuapp.com/alldata/?remboursement=false')

# %%
data_all_rembourse
# Out:
#        PAYMENT_RATE EXT_SOURCE_1 EXT_SOURCE_3 EXT_SOURCE_2  DAYS_BIRTH  \
# 100003     0.027598     0.311267       Indisp     0.622246       16765
# 100004         0.05       Indisp     0.729567     0.555912       19046
# 100006     0.094941       Indisp       Indisp     0.650442       19005
# 100007     0.042623       Indisp       Indisp     0.322738       19932
# 100008     0.056101       Indisp     0.621226     0.354225       16941
# ...             ...          ...          ...          ...         ...
# 100110     0.067173       Indisp     0.328063     0.640549       10744
# 100111     0.032408     0.563323     0.228883     0.608604       10485
# 100113       0.0496     0.475762      0.78988     0.593019       15137
# 100116     0.035575     0.671272     0.071055     0.700274       14751
# 100118      0.03932       Indisp       Indisp     0.626303       22471
#
#        AMT_ANNUITY DAYS_EMPLOYED APPROVED_CNT_PAYMENT_MEAN  DAYS_ID_PUBLISH  \
# 100003     35698.5        1188.0                      10.0              291
# 100004      6750.0         225.0                       4.0             2531
# 100006     29686.5        3039.0                      18.0             2437
# 100007     21865.5        3038.0                 20.666667             3458
# 100008     27517.5        1588.0                      14.0              477
# ...            ...           ...                       ...              ...
# 100110     25065.0         741.0                      10.5             2381
# 100111     27954.0        1249.0                      11.2             3110
# 100113      6696.0        7980.0                       9.0             4576
# 100116     32017.5        6737.0                      11.2             4788
# 100118     26541.0        Indisp                      10.0             4323
#
#        INCOME_CREDIT_PERC  ... BURO_DAYS_CREDIT_MAX  \
# 100003           0.132217  ...               -606.0
# 100004                0.1  ...               -408.0
# 100006             0.2199  ...               Indisp
# 100007           0.179963  ...              -1149.0
# 100008           0.277955  ...                -78.0
# ...                   ...  ...                  ...
# 100110           0.185667  ...                -86.0
# 100111            0.24848  ...               -270.0
# 100113           0.087529  ...               -753.0
# 100116           0.131759  ...               -104.0
# 100118             0.2949  ...               Indisp
#
#        BURO_DAYS_CREDIT_ENDDATE_MAX INSTAL_AMT_PAYMENT_MIN  \
# 100003                       1216.0                6662.97
# 100004                       -382.0                5357.25
# 100006                       Indisp                2482.92
# 100007                       -783.0                   0.18
# 100008                        471.0                 227.16
# ...                             ...                    ...
# 100110                        218.0                 8232.3
# 100111                       9233.0                1897.65
# 100113                       1073.0                  6.615
# 100116                      31066.0                   9.81
# 100118                       Indisp              15233.175
#
#        ACTIVE_DAYS_CREDIT_ENDDATE_MAX ACTIVE_DAYS_CREDIT_MEAN INSTAL_DBD_MAX  \
# 100003                         1216.0                  -606.0           14.0
# 100004                         Indisp                  Indisp           11.0
# 100006                         Indisp                  Indisp           77.0
# 100007                         Indisp                  Indisp           31.0
# 100008                          471.0                   -78.0           28.0
# ...                               ...                     ...            ...
# 100110                          218.0                   -86.0           29.0
# 100111                           98.0             -325.333333           85.0
# 100113                         1073.0                  -776.5           40.0
# 100116                        31066.0                -662.875           95.0
# 100118                         Indisp                  Indisp           14.0
#
#        CLOSED_AMT_CREDIT_SUM_MEAN BURO_AMT_CREDIT_SUM_DEBT_MEAN  \
# 100003                    69133.5                           0.0
# 100004                    94518.9                           0.0
# 100006                     Indisp                        Indisp
# 100007                   146250.0                           0.0
# 100008                  100419.75                       80019.0
# ...                           ...                           ...
# 100110                     Indisp                     52820.595
# 100111                 242554.635                   13009.03875
# 100113                    43722.0                      133789.5
# 100116                 352153.525                 142965.518824
# 100118                     Indisp                        Indisp
#
#        ACTIVE_DAYS_CREDIT_ENDDATE_MEAN PROBABILITY
# 100003                          1216.0        0.31
# 100004                          Indisp        0.23
# 100006                          Indisp        0.31
# 100007                          Indisp        0.41
# 100008                           471.0        0.29
# ...                                ...         ...
# 100110                           218.0        0.47
# 100111                            98.0        0.36
# 100113                          1049.5        0.22
# 100116                         4146.75        0.46
# 100118                          Indisp        0.29
#
# [61 rows x 41 columns]
